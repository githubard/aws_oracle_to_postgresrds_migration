# %%
Step 6: Create AWS DMS Source and Target Endpoints
------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Change the source oracle-bosdbdev server name from public IP to private IP like below

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Add inbound rule in ec2 security group to allow replication instance connection with oracle port 1521

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Add inbound rule in bosdevb01 postgres security group to allow replication instance connection with postgres port 5432

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
