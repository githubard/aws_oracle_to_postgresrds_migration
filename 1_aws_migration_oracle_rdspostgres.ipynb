# %%
Create source oracle database inside an EC2 instance ( EC2 instance public accesible )
---------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
[ec2-user@ip-10-50-10-222 tmp]$ sudo yum localinstall oracle-database-preinstall-19c-1.0-2.el8.x86_64.rpm

[ec2-user@ip-10-50-10-222 ~]$ sudo passwd oracle

[ec2-user@ip-10-50-10-222 ~]$ sudo mkdir -p /u01/app/oracle/product/19.3/db_home
[ec2-user@ip-10-50-10-222 ~]$ sudo chown -R oracle:oinstall /u01
[ec2-user@ip-10-50-10-222 ~]$ sudo chmod -R 775 /u01
[ec2-user@ip-10-50-10-222 ~]$ su - oracle
Password:
[oracle@ip-10-50-10-222 ~]$ cat .bash_profile
# .bash_profile
# Get the aliases and functions
if [ -f ~/.bashrc ]; then
        . ~/.bashrc
fi
# User specific environment and startup programs
export ORACLE_SID=BOSDEVDB
export ORACLE_BASE=/u01/app/oracle
export ORACLE_HOME=/u01/app/oracle/product/19.3/db_home
PATH=$PATH:$HOME/.local/bin:$ORACLE_HOME/bin
export PATH

[oracle@ip-10-50-10-222 ~]$ . .bash_profile

# %%
[oracle@ip-10-50-10-222]$ cd $ORACLE_HOME

[oracle@ip-10-50-10-222 db_home]$ unzip /tmp/LINUX.X64_193000_db_home.zip

[ec2-user@ip-10-50-10-222 ~]$ sudo yum install xorg-x11-xauth  -- already installed

[ec2-user@ip-10-50-10-222 ~]$ sudo yum install xterm

[oracle@ip-10-50-10-222 db_home]$ export CV_ASSUME_DISTID=OEL7.8

[oracle@ip-10-50-10-222 ~]$ ./runInstaller

[oracle@ip-10-50-10-222 ~]$ dbca

[oracle@ip-10-50-10-222 ~]$ ps -ef | grep pmon | grep -v grep
oracle     28120       1  0 20:16 ?        00:00:00 ora_pmon_bosdbdev
[oracle@ip-10-50-10-222 ~]$

[oracle@ip-10-50-10-222 ~]$ ps -ef | grep tnsl | grep -v grep
oracle     26385       1  0 19:58 ?        00:00:00 /u01/app/oracle/product/19.3/db_home/bin/tnslsnr LISTENER -inherit
[oracle@ip-10-50-10-222 ~]$

SQL> select INSTANCE_NAME,HOST_NAME,VERSION,STATUS,INSTANCE_ROLE from v$instance;

INSTANCE_NAME    HOST_NAME                                                        VERSION           STATUS       INSTANCE_ROLE
---------------- ---------------------------------------------------------------- ----------------- ------------ ------------------
bosdbdev         ip-10-50-10-222.ap-south-1.compute.internal                      19.0.0.0.0        OPEN         PRIMARY_INSTANCE

# %%
Edit EC2 security group ingress ( inbound rules ) to allow SSH port 22 and Oracle Port 1521 
--------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Update Oracle Listener Host to 0.0.0.0 to allow all ips in the server and add SID as below 
------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Test connection ( dbeaver client ) to EC2 Oracle Database from local with Host as EC2 public IP 
---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)
